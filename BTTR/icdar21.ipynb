# %% [markdown]
# # Head

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %% [markdown]
# Lembre de alterar o BASE_DIR conforme local da sua máquina

# %%
#BASE_DIR = 'drive/MyDrive/Rural/2022.1/projeto/Imagem/artigos/icdar21'
BASE_DIR = 'drive/MyDrive/Colab/imagem/icdar21'
# %cd $BASE_DIR
# Out:
# /content/drive/MyDrive/Colab/imagem/icdar21

# %%
# clone project   
#!git clone https://github.com/Green-Wood/BTTR

# %% [markdown]
# ## Install git project

# %%
#Para instalar o projeto
# %cd BTTR
# !conda create -y -n bttr python=3.7
# !source activate bttr
# !conda install --yes -c pytorch pytorch=1.7.0 torchvision cudatoolkit
# !pip install -e .

# %% [markdown]
# **Você deve reiniciar o ambiente após intalá-lo** e seguir para a próxima célula

# %% [markdown]
# # Rodar projeto após instalá-lo

# %% [markdown]
# Novamente lembrar alterar o BASE_DIR com o diretório local

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
BASE_DIR = 'drive/MyDrive/Colab/imagem/icdar21'
# %cd $BASE_DIR
# %cd BTTR
# !source activate bttr

# %%
# !pip install torchmetrics==0.7
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 396 kB 4.6 MB/s
# ...
#   Attempting uninstall: torchmetrics
#     Found existing installation: torchmetrics 0.11.4
#     Uninstalling torchmetrics-0.11.4:
#       Successfully uninstalled torchmetrics-0.11.4
# ...

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 61.8 MB 1.3 MB/s
# ...

# %%
# !python train.py --config config.yaml
# Out:
# Init vocab with size: 20
# Global seed set to 7
# Load data from: Base_soma_subtracao.zip
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
#
#
# ENTREI NO SETUP
# ...

# %%
#apenas testando
import torch, torchvision
from torchvision import transforms
print(torchvision.__version__)
dir(transforms)
# Out:
# 0.15.1+cu118
# ['AugMix',
#  'AutoAugment',
#  'AutoAugmentPolicy',
#  'CenterCrop',
#  'ColorJitter',
#  'Compose',
#  'ConvertImageDtype',
#  'ElasticTransform',
#  'FiveCrop',
#  'GaussianBlur',
#  'Grayscale',
#  'InterpolationMode',
#  'Lambda',
#  'LinearTransformation',
#  'Normalize',
#  'PILToTensor',
#  'Pad',
#  'RandAugment',
#  'RandomAdjustSharpness',
#  'RandomAffine',
#  'RandomApply',
#  'RandomAutocontrast',
#  'RandomChoice',
#  'RandomCrop',
#  'RandomEqualize',
#  'RandomErasing',
#  'RandomGrayscale',
#  'RandomHorizontalFlip',
#  'RandomInvert',
#  'RandomOrder',
#  'RandomPerspective',
#  'RandomPosterize',
#  'RandomResizedCrop',
#  'RandomRotation',
#  'RandomSolarize',
#  'RandomVerticalFlip',
#  'Resize',
#  'TenCrop',
#  'ToPILImage',
#  'ToTensor',
#  'TrivialAugmentWide',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_functional_pil',
# ...

# %%
#apenas testando
import torch
print(torch.cuda.device_count())
print(torch.cuda.device_count())
torch.cuda.is_available()
# Out:
# 1
# 1
# True
